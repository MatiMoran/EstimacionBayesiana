# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import logging
import time
from threading import Thread
from team_scrap import *

logpath = "players_penalties.csv"
logger = logging.getLogger('log')
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(message)s')

file_handler = logging.FileHandler(logpath)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

console_handler = logging.StreamHandler()
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# %%
player_df = pd.read_csv('kaggle/players.csv')
player_df = player_df[player_df['last_season'] >= 2023]
player_df = player_df[player_df['current_club_domestic_competition_id'].isin(['GB1', 'ES1', 'IT1', 'L1'])] # only premier, la liga serie a and bundesliga
player_df = player_df[player_df['position'].isin(['Midfield', 'Attack'])]
player_df
# Out:
#        player_id first_name           last_name                        name  \
# 188         3333      James              Milner                James Milner
# 644         7161      Jonas             Hofmann               Jonas Hofmann
# 1385       16306        NaN            Casemiro                    Casemiro
# 1559       18644     Álvaro             Negredo              Álvaro Negredo
# 1677       20005        NaN          Papu Gómez                  Papu Gómez
# ...          ...        ...                 ...                         ...
# 31517    1203143    Dominic  Dos Santos Martins  Dominic Dos Santos Martins
# 31520    1210422  Aboubacar            Bassinga          Aboubacar Bassinga
# 31524    1222050      Rocco             Di Vico               Rocco Di Vico
# 31531    1230202      Borja             Vázquez               Borja Vázquez
# 31552    1255616    Alberto               Risco               Alberto Risco
#
#        last_season  current_club_id                 player_code  \
# 188           2023             1237                james-milner
# 644           2023               15               jonas-hofmann
# 1385          2023              985                    casemiro
# 1559          2023             2687              alvaro-negredo
# 1677          2023             2919                  papu-gomez
# ...            ...              ...                         ...
# 31517         2023             1031  dominic-dos-santos-martins
# 31520         2023              472          aboubacar-bassinga
# 31524         2023              380               rocco-di-vico
# 31531         2023             2687               borja-vazquez
# 31552         2023             3709               alberto-risco
#
#       country_of_birth         city_of_birth country_of_citizenship  ...  \
# 188            England                 Leeds                England  ...
# 644            Germany            Heidelberg                Germany  ...
# 1385            Brazil   São José dos Campos                 Brazil  ...
# 1559             Spain                Madrid                  Spain  ...
# 1677         Argentina          Buenos Aires              Argentina  ...
# ...                ...                   ...                    ...  ...
# 31517              NaN                   NaN               Portugal  ...
# 31520              NaN                   NaN          Cote d'Ivoire  ...
# 31524              NaN                   NaN                  Italy  ...
# 31531            Spain  Jerez de la Frontera                  Spain  ...
# 31552            Spain               Córdoba                  Spain  ...
#
#         foot height_in_cm contract_expiration_date            agent_name  \
# 188    right        175.0      2025-06-30 00:00:00                   NaN
# 644    right        176.0      2027-06-30 00:00:00  Dr. Marco Gutfleisch
# 1385   right        185.0      2026-06-30 00:00:00           Best of You
# 1559    left        186.0                      NaN                   NaN
# 1677   right        167.0                      NaN             GR Sports
# ...      ...          ...                      ...                   ...
# 31517    NaN          NaN      2025-06-30 00:00:00                   NaN
# 31520    NaN          NaN                      NaN    Gesport Espizua SL
# 31524    NaN          NaN                      NaN                   NaN
# 31531    NaN          NaN      2026-06-30 00:00:00    Gesport Espizua SL
# 31552    NaN          NaN      2026-06-30 00:00:00           Best of You
#
#                                                image_url  \
# 188    https://img.a.transfermarkt.technology/portrai...
# 644    https://img.a.transfermarkt.technology/portrai...
# 1385   https://img.a.transfermarkt.technology/portrai...
# 1559   https://img.a.transfermarkt.technology/portrai...
# 1677   https://img.a.transfermarkt.technology/portrai...
# ...                                                  ...
# 31517  https://img.a.transfermarkt.technology/portrai...
# 31520  https://img.a.transfermarkt.technology/portrai...
# 31524  https://img.a.transfermarkt.technology/portrai...
# 31531  https://img.a.transfermarkt.technology/portrai...
# 31552  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url  \
# 188    https://www.transfermarkt.co.uk/james-milner/p...
# 644    https://www.transfermarkt.co.uk/jonas-hofmann/...
# 1385   https://www.transfermarkt.co.uk/casemiro/profi...
# 1559   https://www.transfermarkt.co.uk/alvaro-negredo...
# 1677   https://www.transfermarkt.co.uk/papu-gomez/pro...
# ...                                                  ...
# 31517  https://www.transfermarkt.co.uk/dominic-dos-sa...
# 31520  https://www.transfermarkt.co.uk/aboubacar-bass...
# 31524  https://www.transfermarkt.co.uk/rocco-di-vico/...
# 31531  https://www.transfermarkt.co.uk/borja-vazquez/...
# 31552  https://www.transfermarkt.co.uk/alberto-risco/...
#
#       current_club_domestic_competition_id       current_club_name  \
# 188                                    GB1  Brighton & Hove Albion
# 644                                     L1     Bayer 04 Leverkusen
# 1385                                   GB1       Manchester United
# 1559                                   ES1                Cádiz CF
# 1677                                   IT1                AC Monza
# ...                                    ...                     ...
# 31517                                  GB1              Luton Town
# 31520                                  ES1           UD Las Palmas
# 31524                                  IT1     US Salernitana 1919
# 31531                                  ES1                Cádiz CF
# 31552                                  ES1               Getafe CF
#
#       market_value_in_eur highest_market_value_in_eur
# 188             1000000.0                  21000000.0
# 644            10000000.0                  16000000.0
# 1385           20000000.0                  80000000.0
# 1559             300000.0                  27000000.0
# 1677            2000000.0                  18000000.0
# ...                   ...                         ...
# 31517                 NaN                         NaN
# 31520                 NaN                         NaN
# 31524                 NaN                         NaN
# 31531             50000.0                     50000.0
# 31552                 NaN                         NaN
#
# [1559 rows x 23 columns]

# %%
def get_players_data(players_ids: list[int]):
    for player_id in players_ids:
        try:
            player_name, pk1, pk2 = get_player_data(player_id)
            logger.info(f"{player_name},{pk1},{pk2}")
            time.sleep(0.001)
        except KeyError:
            time.sleep(0.001)

# %%
def main():
    players_ids = player_df["player_id"].to_list()
    sublists = [players_ids[i:i + len(players_ids) // 10] for i in range(0, len(players_ids), len(players_ids) // 10)]

    threads = []
    for sublist in sublists:
        t = Thread(target=get_players_data, args=(sublist,))
        threads.append(t)
        t.start()

    # wait for the threads to complete
    for t in threads:
        t.join()

main()
# Out:
# fetching player 3333
# fetching player 128223
# fetching player 221899
# fetching player 293169
# fetching player 355369
# fetching player 433818
# fetching player 538810
# fetching player 634431
# fetching player 724537
# fetching player 892929
# fetching player 1111820
# #77JosipBrekalo,1,2
# #77JosipBrekalo,1,2
# fetching player 293200
# #16ChrisRamos,0,0
# #16ChrisRamos,0,0
# #72JuniorAjayi,0,0
# #72JuniorAjayi,0,0
# #24AndrewMoran,0,1
# #30HugoÁlvarez,2,0
# #24AndrewMoran,0,1
# #30HugoÁlvarez,2,0
# fetching player 538971
# fetching player 1129800
# fetching player 724783
# fetching player 892973
# #10NikolaVlašić,9,5
# #10ScottTwine,1,1
# #10NikolaVlašić,9,5
# #22BeñatTurrientes,0,0
# #10ScottTwine,1,1
# #22BeñatTurrientes,0,0
# #7ÁlvaroMorata,14,4
# #12Léo Baptistão,2,1
# #7ÁlvaroMorata,14,4
# #12Léo Baptistão,2,1
# #29NaouirouAhamada,0,0
# #29NaouirouAhamada,0,0
# fetching player 293281
# fetching player 434433
# fetching player 636119
# fetching player 129078
# fetching player 221958
# fetching player 539134
# #14LovroZvonarek,0,0
# #14LovroZvonarek,0,0
# #17Jordan,10,3
# #17Jordan,10,3
# #9NikolaKrstovic,5,5
# #9NikolaKrstovic,5,5
# fetching player 895074
# fetching player 355861
# fetching player 434675
# #11MarcoCamus,1,0
# #11MarcoCamus,1,0
# TawandaChirewa,1,1
# TawandaChirewa,1,1
# #6JamesMilner,30,5
# #6JamesMilner,30,5
# #17RomanYaremchuk,6,5
# fetching player 636695
# fetching player 726526
# fetching player 7161
# #17RomanYaremchuk,6,5
# #14DanielMaldini,5,0
# #15NathanRedmond,0,0
# #14DanielMaldini,5,0
# LucaBoncori,3,0
# #15NathanRedmond,0,0
# LucaBoncori,3,0
# fetching player 223725
# fetching player 539810
# fetching player 129476
# fetching player 1172645
# #20MahamadouSusoho,0,0
# #20MahamadouSusoho,0,0
# #10StefanMitrović,1,0
# #10StefanMitrović,1,0
# #17MarcCasadó,0,0
# #17MarcCasadó,0,0
# fetching player 895331
# fetching player 726701
# fetching player 636703
# #9ArnautDanjuma,5,4
# #9ArnautDanjuma,5,4
# #23MunirEl Haddadi,0,1
# #23MunirEl Haddadi,0,1
# EmilioBallard-Matthews,0,0
# EmilioBallard-Matthews,0,0
# fetching player 356141
# fetching player 223967
# fetching player 1184137
# #29JacobBruun Larsen,5,1
# #29JacobBruun Larsen,5,1
# #39KristianSekularac,1,0
# #39KristianSekularac,1,0
# #8DaniPérez,0,0
# #16FermínLópez,0,0
# #8DaniPérez,0,0
# #16FermínLópez,0,0
# #18CodyGakpo,4,1
# GerardDeulofeu,12,0
# #18CodyGakpo,4,1
# GerardDeulofeu,12,0
# fetching player 293385
# fetching player 540333
# fetching player 895480
# fetching player 638793
# fetching player 434990
# #91RodrigoRibeiro,1,1
# #91RodrigoRibeiro,1,1
# #18DaichiKamada,5,1
# #18DaichiKamada,5,1
# #27KonradLaimer,0,0
# #27KonradLaimer,0,0
# fetching player 130360
# fetching player 726859
# fetching player 357158
# fetching player 223979
# #7JonasHofmann,11,2
# #7JonasHofmann,11,2
# fetching player 16306
# #11YassinTallal,0,0
# #11YassinTallal,0,0
# #20DaniOlmo,4,1
# #20DaniOlmo,4,1
# #23AduAres,1,0
# #23AduAres,1,0
# fetching player 1203143
# fetching player 293569
# fetching player 897479
# #17TajonBuchanan,0,0
# #17TajonBuchanan,0,0
# #7ÁlexSola,0,0
# #19RúbenVinagre,0,0
# #7ÁlexSola,0,0
# #31TomasSuslov,5,3
# #19RúbenVinagre,0,0
# #31TomasSuslov,5,3
# #9JoeHugill,5,2
# #9JoeHugill,5,2
# fetching player 640026
# fetching player 435648
# fetching player 357164
# fetching player 540536
# #18Casemiro,0,0
# #24XaverSchlager,0,0
# #18Casemiro,0,0
# #24XaverSchlager,0,0
# #10BennitBröger,0,0
# #10BennitBröger,0,0
# fetching player 18644
# fetching player 730484
# fetching player 225020
# fetching player 898356
# #48DominicDos Santos Martins,0,0
# #48DominicDos Santos Martins,0,0
# #90SimoneVerdi,15,0
# #90SimoneVerdi,15,0
# #10RafaelLeão,2,1
# #10RafaelLeão,2,1
# #8JoshBrownhill,0,0
# fetching player 1210422
# fetching player 130394
# #8JoshBrownhill,0,0
# #21AlessandroBerretta,0,0
# #21AlessandroBerretta,0,0
# #32AaronZehnter,0,0
# #32AaronZehnter,0,0
# fetching player 357233
# fetching player 294057
# fetching player 904974
# fetching player 730486
# #47SholaShoretire,2,1
# #47SholaShoretire,2,1
# #11JoshuaZirkzee,5,1
# #11JoshuaZirkzee,5,1
# #7CarlosVicente,7,0
# MarianoDíaz,4,0
# #7CarlosVicente,7,0
# MarianoDíaz,4,0
# fetching player 640428
# fetching player 435772
# fetching player 540941
# AboubacarBassinga,0,0
# AboubacarBassinga,0,0
# ÁlvaroNegredo,40,8
# ÁlvaroNegredo,40,8
# #18LeandroBarreiro,0,0
# #18LeandroBarreiro,0,0
# fetching player 225122
# fetching player 1222050
# fetching player 20005
# fetching player 357498
# #36NoëlAséko Nkili,0,0
# #42MahmutKücüksahin,0,0
# #36NoëlAséko Nkili,0,0
# #42MahmutKücüksahin,0,0
# #6EduardoCamavinga,0,0
# #6EduardoCamavinga,0,0
# #9GianlucaLapadula,21,7
# #9GianlucaLapadula,21,7
# #17CharlesDe Ketelaere,1,0
# RoccoDi Vico,0,0
# #17CharlesDe Ketelaere,1,0
# #10JamesMaddison,6,2
# RoccoDi Vico,0,0
# #10JamesMaddison,6,2
# #29GonçaloGuedes,4,1
# fetching player 906025
# fetching player 731525
# fetching player 641537
# fetching player 131275
# fetching player 438315
# fetching player 1230202
# #24MikkelDamsgaard,0,0
# #29GonçaloGuedes,4,1
# #24MikkelDamsgaard,0,0
# #9DušanVlahović,23,4
# #9DušanVlahović,23,4
# Papu Gómez,6,4
# Papu Gómez,6,4
# fetching player 294791
# fetching player 225462
# fetching player 542336
# fetching player 357565
# fetching player 20506
# #35TommasoBaldanzi,1,0
# #35TommasoBaldanzi,1,0
# #16RicardArtero,0,0
# #16RicardArtero,0,0
# #19BorjaVázquez,0,0
# #19BorjaVázquez,0,0
# #16AndreasMüller,0,1
# #16AndreasMüller,0,1
# fetching player 642689
# fetching player 907219
# fetching player 1255616
# #84NikolaSekulov,0,1
# #23RareșBurnete,6,1
# #84NikolaSekulov,0,1
# José Mari,3,0
# #23RareșBurnete,6,1
# #11ChocoLozano,3,1
# José Mari,3,0
# #11ChocoLozano,3,1
# #16Rodri,3,0
# #16Rodri,3,0
# fetching player 439292
# fetching player 542819
# fetching player 732096
# fetching player 225873
# fetching player 131731
# #9ChrisBedia,12,2
# #9ChrisBedia,12,2
# Mikael,3,0
# Mikael,3,0
# fetching player 357662
# fetching player 295183
# fetching player 644401
# #18AxelPiesold,0,0
# #18AxelPiesold,0,0
# #18AndrésGuardado,15,3
# #18AndrésGuardado,15,3
# #14AlbertoRisco,0,0
# #14AlbertoRisco,0,0
# fetching player 907489
# fetching player 25488
# #19SantiGarcía,4,0
# #19SantiGarcía,4,0
# #28MilutinOsmajic,1,2
# #28MilutinOsmajic,1,2
# #10MehdiBourabia,1,0
# #10MehdiBourabia,1,0
# fetching player 732119
# fetching player 543387
# fetching player 131978
# #23KeaneLewis-Potter,0,0
# #23KeaneLewis-Potter,0,0
# #77KarolLinetty,0,0
# #77KarolLinetty,0,0
# fetching player 645774
# fetching player 226025
# #40LucaRaimund,0,0
# #18Sydneyvan Hooijdonk,10,0
# #40LucaRaimund,0,0
# #18Sydneyvan Hooijdonk,10,0
# #41DeclanRice,1,2
# #41DeclanRice,1,2
# #18ErenDinkci,0,1
# #18ErenDinkci,0,1
# fetching player 907813
# fetching player 441515
# fetching player 357885
# fetching player 646658
# #18RăzvanMarin,10,2
# #18RăzvanMarin,10,2
# #49KaideGordon,2,1
# #49KaideGordon,2,1
# #36LucaMazzitelli,3,0
# #36LucaMazzitelli,3,0
# fetching player 732507
# fetching player 295313
# fetching player 226524
# #6RossBarkley,3,2
# #6RossBarkley,3,2
# #28CheickDoucouré,0,0
# #28CheickDoucouré,0,0
# fetching player 131996
# fetching player 543771
# #18PabloFornals,0,0
# #18PabloFornals,0,0
# #11DanielBoloca,0,0
# #11DanielBoloca,0,0
# #28PabloMarín,1,0
# #28PabloMarín,1,0
# #19AgustínMartegani,0,0
# #19AgustínMartegani,0,0
# #2MortenThorsby,0,0
# fetching player 358008
# fetching player 442703
# fetching player 908798
# #2MortenThorsby,0,0
# #21AaronRamsey,0,0
# #9TaiwoAwoniyi,3,0
# #21AaronRamsey,0,0
# #9TaiwoAwoniyi,3,0
# #20BertrandTraoré,5,1
# #20BertrandTraoré,5,1
# fetching player 733576
# fetching player 226973
# fetching player 646734
# fetching player 295331
# fetching player 132098
# AntonioCandreva,26,7
# AntonioCandreva,26,7
# fetching player 27992
# #20YlberRamadani,0,0
# #20YlberRamadani,0,0
# #21KristjanAsllani,8,0
# #65MatthewWhittingham,0,0
# #21KristjanAsllani,8,0
# #65MatthewWhittingham,0,0
# #6TomásMendes,0,0
# #6TomásMendes,0,0
# fetching player 442805
# fetching player 544148
# fetching player 908952
# fetching player 646735
# #6HarrisonReed,0,1
# #6HarrisonReed,0,1
# #10AlbertoMoleiro,0,0
# #10AlbertoMoleiro,0,0
# fetching player 227081
# #10LukaModric,23,6
# --- Logging error ---
# fetching player 734425
# Traceback (most recent call last):
# Exception in thread Thread-46 (get_players_data):
# Traceback (most recent call last):
#   File "/usr/lib64/python3.12/logging/__init__.py", line 1163, in emit
# IsaacSuccess,3,1
#     stream.write(msg + self.terminator)
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 694, in write
# IsaacSuccess,3,1
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
# #9HarryKane,75,11
#     self._event_pipe.send(b"")
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib64/python3.12/site-packages/zmq/sugar/socket.py", line 701, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_zmq.py", line 1092, in zmq.backend.cython._zmq.Socket.send
# #9HarryKane,75,11
# #10AitorGismera,0,0
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Thread(Thread-46 (get_players_data), stopped 139823685830336)>>
# Traceback (most recent call last):
#   File "/usr/lib64/python3.12/threading.py", line 1030, in _bootstrap
# #31TomasCvancara,2,1
# #10AitorGismera,0,0
# object address  : 0x7f2b493e2f20
# object refcount : 2
#     self._bootstrap_inner()
#   File "/usr/lib64/python3.12/threading.py", line 1075, in _bootstrap_inner
# object type     : 0x557434d64f30
# object type name: ZMQError
# object repr     : ZMQError('Socket operation on non-socket')
# lost sys.stderr
# fetching player 296397
# fetching player 133179
#       File "/usr/lib64/python3.12/threading.py", line 1389, in invoke_excepthook
# #15IddrisuBaba,0,0
# #31TomasCvancara,2,1
#     local_print("Exception in threading.excepthook:",
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
# #8TimSchleinitz,0,0
# #15IddrisuBaba,0,0
#     self.pub_thread.schedule(self._flush)
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
# #8TimSchleinitz,0,0
# #70GianlucaGaetano,17,0
# #11JoaquínCorrea,1,2
# #70GianlucaGaetano,17,0
#       File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib64/python3.12/site-packages/zmq/sugar/socket.py", line 701, in send
# #11JoaquínCorrea,1,2
#       File "_zmq.py", line 1092, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1134, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1209, in zmq.backend.cython._zmq._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 604, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/home/matias/Database/files/Vault/files/Repos/UBA/EstimacionBayesiana/.venv/lib64/python3.12/site-packages/zmq/sugar/socket.py", line 701, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_zmq.py", line 1092, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1134, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1209, in zmq.backend.cython._zmq._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# fetching player 646739
# fetching player 545332
# fetching player 443222
# fetching player 909894
# fetching player 358032
# fetching player 227961
# #11MichaelOlakigbe,0,0
# #11MichaelOlakigbe,0,0
# fetching player 735570
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 15
#      12     for t in threads:
#      13         t.join()
# ---> 15 main()
#
# Cell In[20], line 13, in main()
#      11 # wait for the threads to complete
#      12 for t in threads:
# ---> 13     t.join()
#
# File /usr/lib64/python3.12/threading.py:1147, in Thread.join(self, timeout)
#    1144     raise RuntimeError("cannot join current thread")
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1151     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib64/python3.12/threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1164     return
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#    1169         self._stop()
#
# KeyboardInterrupt:
# ÁngelAlarcón,1,0
# ÁngelAlarcón,1,0
# #15Martende Roon,2,1
# #15Martende Roon,2,1
# #29MikkelKaufmann,2,0
# #29MikkelKaufmann,2,0
# #10ArneMaier,1,0
# fetching player 646740
# fetching player 134294
# fetching player 545538
# #10ArneMaier,1,0
# #9MarcCardona,3,0
# #9MarcCardona,3,0
# fetching player 296879
# fetching player 443331
# #14GiacomoCorona,6,1
# #14GiacomoCorona,6,1
# #26CyrilNgonge,3,0
# #26CyrilNgonge,3,0
# fetching player 911328
# fetching player 358166
# #8JoãoGomes,0,0
# #8JoãoGomes,0,0
# fetching player 735571
# #22LameckBanda,1,0
# #22LameckBanda,1,0
# #6PatrickOsterhage,0,0
# #21SteffenTigges,0,1
# #6PatrickOsterhage,0,0
# #6Gavi,0,0
# #21SteffenTigges,0,1
# #6Gavi,0,0
# #77MohamedKaba,0,0
# #77MohamedKaba,0,0
# fetching player 546543
# fetching player 443710
# fetching player 297583
# fetching player 646743
# #18DannyIngs,13,3
# #17JaimeMata,28,4
# #18DannyIngs,13,3
# #17JaimeMata,28,4
# #14EldorShomurodov,2,0
# #14EldorShomurodov,2,0
# #9Rodrigo Muniz,0,0
# #9Rodrigo Muniz,0,0
# fetching player 913955
# fetching player 134425
# fetching player 228645
# fetching player 358504
# fetching player 737138
# #10Woo-yeongJeong,1,1
# #10Woo-yeongJeong,1,1
# #9DarwinNúñez,12,1
# #6JaviNavarro,0,0
# #9DarwinNúñez,12,1
# #6JaviNavarro,0,0
# #6AngeloStiller,1,2
# #6AngeloStiller,1,2
# fetching player 298477
# fetching player 546712
# fetching player 647534
# fetching player 444208
# RaheemSterling,4,5
# RaheemSterling,4,5
# YadamSantana,0,0
# YadamSantana,0,0
# FacuEsnáider,0,0
# FacuEsnáider,0,0
# fetching player 139435
# fetching player 916014
# fetching player 741149
# #42RitsuDoan,4,2
# #42RitsuDoan,4,2
# #29WoutWeghorst,18,12
# #29WoutWeghorst,18,12
# fetching player 360518
# fetching player 229006
# #25AnisSlimane,1,0
# #25AnisSlimane,1,0
# #14MichaelObafemi,2,0
# #14MichaelObafemi,2,0
# #23IsraDomínguez,0,0
# #23IsraDomínguez,0,0
# ElidonQenaj,1,0
# ElidonQenaj,1,0
# fetching player 548111
# fetching player 444523
# fetching player 917014
# fetching player 742201
# #16OliMcBurnie,11,4
# JoelVoelkerling Persson,1,0
# #9FranckHonorat,0,0
# #14DaniRodríguez,7,0
# #16OliMcBurnie,11,4
# #14DaniRodríguez,7,0
# #9FranckHonorat,0,0
# JoelVoelkerling Persson,1,0
# #16ÁlexBaena,0,1
# #16ÁlexBaena,0,1
# fetching player 298575
# fetching player 140776
# fetching player 230784
# fetching player 648046
# fetching player 548729
# #22GiulianoSimeone,1,1
# #22GiulianoSimeone,1,1
# #11KikeBarja,2,0
# #11KikeBarja,2,0
# #10Lucas Paquetá,8,1
# #10Lucas Paquetá,8,1
# #7TeunKoopmeiners,36,7
# #7TeunKoopmeiners,36,7
# #28EvanFerguson,2,1
# #28EvanFerguson,2,1
# fetching player 742521
# fetching player 298635
# fetching player 445939
# fetching player 361065
# fetching player 648195
# #17AsafArania,1,0
# #17AsafArania,1,0
# #5ThomasPartey,0,1
# #5ThomasPartey,0,1
# #25ZekiAmdouni,6,0
# #25ZekiAmdouni,6,0
# fetching player 917015
# fetching player 230818
# fetching player 550106
# #10YannickCarrasco,20,6
# #10YannickCarrasco,20,6
# fetching player 142021
# #22JhonSolís,0,0
# #22JhonSolís,0,0
# #42FabioTorsiello,2,0
# #42FabioTorsiello,2,0
# #20MitchelBakker,0,0
# #20MitchelBakker,0,0
# fetching player 743091
# fetching player 918414
# fetching player 361254
# #10SergiDarder,0,0
# #10SergiDarder,0,0
# #7OmarMarmoush,4,1
# #7OmarMarmoush,4,1
# #20GrigorisKastanos,3,1
# #20GrigorisKastanos,3,1
# #5FabianRüdlin,1,0
# #5FabianRüdlin,1,0
# fetching player 142031
# fetching player 447052
# fetching player 298976
# fetching player 231590
# #8EnzoFernández,6,1
# #8EnzoFernández,6,1
# #22MatteoCancellieri,2,2
# #22MatteoCancellieri,2,2
# #26Emirhanİlkhan,0,0
# #26Emirhanİlkhan,0,0
# fetching player 649016
# fetching player 550108
# fetching player 743387
# #7BraydonManu,0,0
# #7BraydonManu,0,0
# #8PeruNolaskoain,1,0
# #8PeruNolaskoain,1,0
# #11RafaMir,4,1
# #11RafaMir,4,1
# fetching player 232320
# fetching player 447661
# fetching player 361508
# #5OmarMascarell,5,1
# #5OmarMascarell,5,1
# #13ParisBrunner,10,0
# #13ParisBrunner,10,0
# fetching player 143812
# fetching player 921513
# El BilalTouré,4,0
# El BilalTouré,4,0
# #16AtakanKarazor,0,0
# #16AtakanKarazor,0,0
# #59NicolaZalewski,4,1
# #59NicolaZalewski,4,1
# fetching player 649020
# fetching player 232418
# fetching player 550492
# #10StanisIdumbo,3,1
# #10StanisIdumbo,3,1
# fetching player 743395
# #5MatíasVecino,0,0
# #5MatíasVecino,0,0
# #53JoeGardner,0,0
# #11DavidMamutovic,0,0
# #53JoeGardner,0,0
# #11DavidMamutovic,0,0
# fetching player 143891
# fetching player 921532
# fetching player 362086
# #29GiorgiGagua,1,0
# #29GiorgiGagua,1,0
# #6BoubacarTraoré,0,0
# #6BoubacarTraoré,0,0
# #9BorjaMayoral,10,5
# #9BorjaMayoral,10,5
# #26Douglas Luiz,6,2
# #26Douglas Luiz,6,2
# fetching player 550995
# fetching player 649033
# fetching player 300168
# fetching player 448028
# #39NoahMbamba,0,0
# #39NoahMbamba,0,0
# #7IsiPalazón,6,2
# #7IsiPalazón,6,2
# fetching player 743498
# fetching player 362842
# #33OndrejDuda,12,3
# #19Detlef EsapaOsong,7,3
# #33OndrejDuda,12,3
# #19Detlef EsapaOsong,7,3
# #28WilsonOdobert,0,0
# #28WilsonOdobert,0,0
# OwenHesketh,4,0
# OwenHesketh,4,0
# #6DionLopy,2,0
# fetching player 232454
# fetching player 922413
# fetching player 743591
# fetching player 551752
# #6DionLopy,2,0
# #8KevinSessa,3,0
# #8KevinSessa,3,0
# #26MaximilianPhilipp,17,1
# #6MikelVesga,5,1
# #26MaximilianPhilipp,17,1
# #6MikelVesga,5,1
# #18Arthur Melo,1,0
# #18Arthur Melo,1,0
# fetching player 649317
# fetching player 448177
# fetching player 144028
# fetching player 300532
# fetching player 363205
# #26Savinho,0,0
# #26Savinho,0,0
# fetching player 743597
# #29DembaSeck,1,0
# #29DembaSeck,1,0
# #11PontusAlmqvist,0,0
# #11PontusAlmqvist,0,0
# #9JhonDurán,0,0
# #18NadiemAmiri,4,2
# #9JhonDurán,0,0
# #18NadiemAmiri,4,2
# MarkoMladenovic,9,1
# MarkoMladenovic,9,1
# #11Matheus França,0,0
# #11Matheus França,0,0
# fetching player 552057
# fetching player 302215
# fetching player 650224
# fetching player 232463
# fetching player 922462
# #9Gabriel Jesus,6,7
# #9Gabriel Jesus,6,7
# #19LeandroTrossard,10,2
# #19LeandroTrossard,10,2
# fetching player 744149
# fetching player 364133
# fetching player 146310
# #25LucaPfeiffer,2,1
# #25LucaPfeiffer,2,1
# #11LewisKoumas,0,0
# fetching player 233782
# #11LewisKoumas,0,0
# #39ChristosKourfalidis,0,0
# #39ChristosKourfalidis,0,0
# fetching player 922764
# fetching player 650966
# #18NabyKeïta,0,1
# #18NabyKeïta,0,1
# #23AdamHlozek,1,1
# #23AdamHlozek,1,1
# fetching player 303116
# fetching player 552425
# #20AdamWharton,0,0
# #20AdamWharton,0,0
# #7JessicNgankam,15,5
# #7JessicNgankam,15,5
# #63BenParkinson,0,0
# #63BenParkinson,0,0
# fetching player 744728
# fetching player 448344
# fetching player 922769
# #93AïssaLaïdouni,5,1
# #93AïssaLaïdouni,5,1
# fetching player 234029
# #11PietroPellegri,0,0
# #11PietroPellegri,0,0
# #3WataruEndo,7,0
# #7JonMoncayola,0,0
# #3WataruEndo,7,0
# #7JonMoncayola,0,0
# #80SamueleVignato,11,1
# #80SamueleVignato,11,1
# #22GaetanoCastrovilli,0,0
# #22GaetanoCastrovilli,0,0
# #21ÓscarMelendo,0,0
# #21ÓscarMelendo,0,0
# fetching player 364135
# fetching player 146752
# fetching player 552549
# fetching player 651002
# fetching player 303259
# fetching player 449151
# #6GrischaPrömel,0,0
# #6GrischaPrömel,0,0
# fetching player 234523
# #67LewisMiley,0,0
# #67LewisMiley,0,0
# #18GiacomoFaticanti,0,1
# #18GiacomoFaticanti,0,1
# fetching player 923595
# fetching player 652797
# #20MoiseKean,4,0
# #20MoiseKean,4,0
# fetching player 364603
# #10JuniorMessias,0,1
# #97Matheus Henrique,0,0
# #10JuniorMessias,0,1
# #97Matheus Henrique,0,0
# #20ArijonIbrahimovic,7,1
# #20ArijonIbrahimovic,7,1
# #11DodiLukébakio,12,2
# fetching player 451276
# fetching player 554903
# #11DodiLukébakio,12,2
# #10GianlucaCaprari,7,3
# #10GianlucaCaprari,7,3
# #17MicahHamilton,0,0
# #17MicahHamilton,0,0
# fetching player 745436
# fetching player 305274
# fetching player 146795
# fetching player 652979
# #9AntonioSanabria,7,2
# #9AntonioSanabria,7,2
# #32MateoRetegui,14,1
# #32MateoRetegui,14,1
# #20José ManuelArnáiz,3,1
# #20José ManuelArnáiz,3,1
# #16LewisWarrington,0,0
# #16LewisWarrington,0,0
# fetching player 234781
# fetching player 555056
# fetching player 365108
# fetching player 654253
# RyanFraser,0,0
# RyanFraser,0,0
# FredOnyedinma,1,1
# FredOnyedinma,1,1
# fetching player 148252
# fetching player 305947
# #8DominikSzoboszlai,17,1
# #8DominikSzoboszlai,17,1
# fetching player 451403
# SalimAbubakar,0,0
# SalimAbubakar,0,0
# #33MaxMoerstedt,4,2
# #33MaxMoerstedt,4,2
# #43TobyCollyer,0,0
# #43TobyCollyer,0,0
# fetching player 745446
# fetching player 926135
# fetching player 654872
# #22MaxwelCornet,3,2
# #22MaxwelCornet,3,2
# #22IwoKaczmarski,0,0
# #22IwoKaczmarski,0,0
# #11DanNdoye,2,1
# #11DanNdoye,2,1
# fetching player 235931
# fetching player 555820
# fetching player 366948
# #29LaurenzDehl,3,0
# AlbertGudmundsson,17,3
# #29LaurenzDehl,3,0
# AlbertGudmundsson,17,3
# #37OmariKellyman,0,0
# #37OmariKellyman,0,0
# LucaNapolitano,0,0
# LucaNapolitano,0,0
# #8RemoFreuler,7,2
# #8RemoFreuler,7,2
# #5MartínPayero,0,0
# fetching player 452477
# fetching player 306024
# fetching player 926694
# fetching player 745461
# fetching player 148262
# #28MarcelWenig,0,2
# #5MartínPayero,0,0
# #14AlessandroDeiola,0,0
# #28MarcelWenig,0,2
# #16Jailson,1,0
# #14AlessandroDeiola,0,0
# #16Jailson,1,0
# fetching player 654949
# fetching player 557614
# fetching player 236041
# fetching player 367992
# #18ArthurVermeeren,0,0
# #9DominicCalvert-Lewin,8,1
# #18ArthurVermeeren,0,0
# #9DominicCalvert-Lewin,8,1
# #28AlexisBlin,0,0
# #28AlexisBlin,0,0
# #34NathanaëlMbuku,2,1
# #34NathanaëlMbuku,2,1
# #34SekouDiawara,0,0
# #34SekouDiawara,0,0
# fetching player 926849
# fetching player 307052
# fetching player 237125
# fetching player 559263
# JeffHendrick,0,0
# JeffHendrick,0,0
# #30LucaKoleosho,0,0
# #20JuniorAdamu,8,2
# #30LucaKoleosho,0,0
# #20JuniorAdamu,8,2
# #10JesperKarlsson,18,4
# #10JesperKarlsson,18,4
# fetching player 655488
# fetching player 148367
# fetching player 745689
# fetching player 453864
# fetching player 368482
# #14MasayaOkugawa,1,0
# #14MasayaOkugawa,1,0
# #9AdriánNiño,4,0
# #9AdriánNiño,4,0
# #6ChristianNørgaard,0,0
# #6ChristianNørgaard,0,0
# #11GabrielMartinelli,1,0
# #11GabrielMartinelli,1,0
# fetching player 307519
# fetching player 928051
# fetching player 148368
# fetching player 655525
# #9MarvinCuni,2,1
# #9MarvinCuni,2,1
# fetching player 453870
# #14LucaBarrington,2,1
# #14LucaBarrington,2,1
# fetching player 745846
# #19FamaraDiédhiou,17,5
# #19FamaraDiédhiou,17,5
# #24FedeSan Emeterio,0,0
# #24FedeSan Emeterio,0,0
# #17YefersonPaz,0,0
# fetching player 237164
# fetching player 307924
# #17YefersonPaz,0,0
# GerardoFusco,1,0
# GerardoFusco,1,0
# #14FábioCarvalho,3,1
# #7RiccardoOrsolini,17,2
# #14FábioCarvalho,3,1
# #7RiccardoOrsolini,17,2
# MauroBandeira,0,0
# MauroBandeira,0,0
# DivockOrigi,5,4
# DivockOrigi,5,4
# #16BenedictHollerbach,2,0
# #16BenedictHollerbach,2,0
# fetching player 655815
# fetching player 928900
# fetching player 560483
# fetching player 368887
# fetching player 745851
# fetching player 148455
# fetching player 454863
# #9IhlasBebou,5,0
# #9IhlasBebou,5,0
# fetching player 237226
# #60JadanRaymond,0,0
# #60JadanRaymond,0,0
# #8MarvinMehlem,0,0
# #8MarvinMehlem,0,0
# #79ZanosSavva,0,0
# #79ZanosSavva,0,0
# #42SydiePeck,0,0
# fetching player 655990
# fetching player 237617
# fetching player 929494
# #42SydiePeck,0,0
# #13AndrásSchäfer,0,0
# #13AndrásSchäfer,0,0
# #11RandyNteka,4,0
# #10MergimBerisha,11,3
# #11RandyNteka,4,0
# #10MergimBerisha,11,3
# fetching player 746739
# fetching player 455181
# fetching player 560694
# fetching player 308279
# #11LoïsOpenda,14,2
# #11LoïsOpenda,14,2
# #11Mohamed Salah,41,10
# fetching player 369081
# #11Mohamed Salah,41,10
# #83TomHill,0,0
# #83TomHill,0,0
# fetching player 148928
# fetching player 656681
# #19ChukwubuikemIkwuemesi,0,0
# #19ChukwubuikemIkwuemesi,0,0
# #35AndreBrooks,0,0
# #35AndreBrooks,0,0
# CristianHerrera,10,3
# #19Jorgede Frutos,0,0
# CristianHerrera,10,3
# #8LewisO'Brien,0,0
# #19Jorgede Frutos,0,0
# #8LewisO'Brien,0,0
# #8RolandoMandragora,1,1
# #8RolandoMandragora,1,1
# fetching player 929912
# fetching player 746740
# fetching player 237658
# fetching player 455661
# fetching player 561452
# fetching player 309110
# #17SaúlÑíguez,3,2
# #8FedericoValverde,2,0
# #17SaúlÑíguez,3,2
# #8FedericoValverde,2,0
# #21DanielJebbison,0,0
# #21DanielJebbison,0,0
# #20DanChesters,0,0
# #20DanChesters,0,0
# #22VictorBoniface,9,0
# #22VictorBoniface,9,0
# fetching player 153084
# fetching player 369567
# fetching player 746891
# fetching player 562049
# fetching player 657430
# #23BraisMéndez,5,2
# #23BraisMéndez,5,2
# #20MichelAebischer,0,0
# #20MichelAebischer,0,0
# fetching player 309400
# fetching player 238407
# #11KenIzekor,5,2
# #11KenIzekor,5,2
# #18SasaKalajdzic,1,1
# #18SasaKalajdzic,1,1
# #8EdoardoBove,0,0
# fetching player 929943
# fetching player 370846
# #8EdoardoBove,0,0
# #7CristianVolpato,2,0
# #7CristianVolpato,2,0
# #8LeonGoretzka,3,2
# #8LeonGoretzka,3,2
# fetching player 563137
# fetching player 747153
# fetching player 153238
# #12SamúCosta,0,0
# #12SamúCosta,0,0
# #11NickWoltemade,10,1
# #11NickWoltemade,10,1
# #29KaiHavertz,19,1
# #29KaiHavertz,19,1
# fetching player 657817
# fetching player 456492
# fetching player 311178
# #20FrancisOnyeka,2,0
# #20FrancisOnyeka,2,0
# #9AlexanderSørloth,4,3
# #9AlexanderSørloth,4,3
# #22TimothyWeah,0,0
# #22TimothyWeah,0,0
# #44DanielGore,0,0
# #44DanielGore,0,0
# fetching player 930998
# fetching player 238654
# fetching player 370998
# fetching player 748316
# RobertNavarro,4,0
# RobertNavarro,4,0
# #29FarideAlidou,1,0
# #29FarideAlidou,1,0
# #37BenicioBaker-Boaitey,0,0
# #21JonathanViera,25,6
# #37BenicioBaker-Boaitey,0,0
# #21JonathanViera,25,6
# #77GeorgiosKyriakopoulos,0,0
# #77GeorgiosKyriakopoulos,0,0
# fetching player 564305
# fetching player 457221
# fetching player 658536
# fetching player 153427
# fetching player 313830
# #4BartolFranjic,2,0
# #4BartolFranjic,2,0
# #8MichelAdopo,0,0
# #8MichelAdopo,0,0
# #9YannickEduardo,6,0
# #9YannickEduardo,6,0
# fetching player 371998
# fetching player 564785
# fetching player 931567
# #5LucasRobertone,0,0
# #5LucasRobertone,0,0
# #27PabloGaldames,0,0
# #24SimonAdingra,0,0
# fetching player 457422
# #27PabloGaldames,0,0
# #13Juan ManuelCruz,1,0
# #24SimonAdingra,0,0
# #28JaimeBáez,2,1
# #13Juan ManuelCruz,1,0
# #28JaimeBáez,2,1
# #42KristianThorstvedt,1,0
# #42KristianThorstvedt,1,0
# #10Bebé,2,1
# #10Bebé,2,1
# fetching player 314210
# fetching player 659331
# fetching player 748319
# fetching player 239949
# fetching player 565435
# fetching player 157501
# #7Vinicius Junior,4,1
# #7Vinicius Junior,4,1
# fetching player 372445
# #9SamueleMulattieri,0,0
# #9SamueleMulattieri,0,0
# #7StivenShpendi,6,2
# #7StivenShpendi,6,2
# #11John-KymaniGordon,0,0
# #27ArneEngels,4,1
# #11John-KymaniGordon,0,0
# #22TomDavies,0,1
# #27ArneEngels,4,1
# #9JamalLowe,4,1
# #22TomDavies,0,1
# #9JamalLowe,4,1
# #22CarlosAlcaraz,0,1
# #22CarlosAlcaraz,0,1
# fetching player 457673
# fetching player 931838
# fetching player 659415
# fetching player 565822
# fetching player 314288
# fetching player 240252
# fetching player 748807
# #21Dani Silva,0,0
# #21Dani Silva,0,0
# fetching player 374954
